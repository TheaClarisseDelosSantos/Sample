# %%
import pandas as pd
import matplotlib .pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('datasets/NYC_Patient Demographics2017.csv')
display(df)
# Out:
#         Survey Year Program Category         Region Served Age Group     Sex  \
# 0              2017       OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 1              2017          SUPPORT        WESTERN REGION     ADULT  FEMALE
# 2              2017       OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 3              2017       OUTPATIENT  NEW YORK CITY REGION     ADULT  FEMALE
# 4              2017       OUTPATIENT     CENTRAL NY REGION     ADULT    MALE
# ...             ...              ...                   ...       ...     ...
# 187187         2017      RESIDENTIAL        WESTERN REGION     ADULT    MALE
# 187188         2017       OUTPATIENT        WESTERN REGION     ADULT    MALE
# 187189         2017        EMERGENCY        WESTERN REGION     ADULT  FEMALE
# 187190         2017      RESIDENTIAL  NEW YORK CITY REGION     ADULT  FEMALE
# 187191         2017       OUTPATIENT     CENTRAL NY REGION     CHILD  FEMALE
#
#                 Transgender        Sexual Orientation  \
# 0       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 1       NO, NOT TRANSGENDER                   UNKNOWN
# 2       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 3       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 4       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# ...                     ...                       ...
# 187187  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187188  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187189  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187190  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187191  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
#
#              Hispanic Ethnicity          Race        Living Situation  ...  \
# 0       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
# 1       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
# 2       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
# 3       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
# 4       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
# ...                         ...           ...                     ...  ...
# 187187     YES, HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION  ...
# 187188  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION  ...
# 187189  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION  ...
# 187190     YES, HISPANIC/LATINO  MULTI-RACIAL  OTHER LIVING SITUATION  ...
# 187191  NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE  ...
#
#        Unknown Insurance Coverage No Insurance Medicaid Insurance  \
# 0                              NO           NO                YES
# 1                              NO           NO                YES
# 2                              NO           NO                YES
# 3                              NO           NO                YES
# 4                             YES           NO                 NO
# ...                           ...          ...                ...
# 187187                         NO           NO                YES
# 187188                         NO           NO                YES
# 187189                         NO           NO                YES
# 187190                         NO           NO                YES
# 187191                         NO           NO                YES
#
#        Medicaid Managed Insurance Medicare Insurance Private Insurance  \
# 0                             YES                 NO                NO
# 1                         UNKNOWN                YES                NO
# 2                              NO                 NO                NO
# 3                              NO                YES                NO
# 4                  NOT APPLICABLE                 NO                NO
# ...                           ...                ...               ...
# 187187                        YES                 NO                NO
# 187188                        YES                YES                NO
# 187189                        YES                 NO                NO
# 187190                         NO                 NO                NO
# 187191                         NO                 NO                NO
#
#        Child Health Plus Insurance Other Insurance Criminal Justice Status  \
# 0                               NO              NO                      NO
# 1                               NO              NO                 UNKNOWN
# 2                               NO              NO                      NO
# 3                               NO              NO                      NO
# 4                               NO              NO                      NO
# ...                            ...             ...                     ...
# 187187                          NO              NO                      NO
# 187188                          NO              NO                     YES
# 187189                          NO              NO                     YES
# 187190                          NO              NO                      NO
# 187191                          NO              NO                      NO
#
#        Three Digit Residence Zip Code
# 0                                 132
# 1                                 146
# 2                                 131
# 3                                 112
# 4                                 130
# ...                               ...
# 187187                            142
# 187188                            142
# 187189                            888
# 187190                            104
# 187191                            132
#
# [187192 rows x 67 columns]

# %%
list(df.columns)
# Out:
# ['Survey Year',
#  'Program Category',
#  'Region Served',
#  'Age Group',
#  'Sex',
#  'Transgender',
#  'Sexual Orientation',
#  'Hispanic Ethnicity',
#  'Race',
#  'Living Situation',
#  'Household Composition',
#  'Preferred Language',
#  'Veteran Status',
#  'Employment Status',
#  'Number Of Hours Worked Each Week',
#  'Education Status',
#  'Special Education Services',
#  'Mental Illness',
#  'Intellectual Disability',
#  'Autism Spectrum',
#  'Other Developmental Disability',
#  'Alcohol Related Disorder',
#  'Drug Substance Disorder',
#  'Mobility Impairment Disorder',
#  'Hearing Visual Impairment',
#  'Hyperlipidemia',
#  'High Blood Pressure',
#  'Diabetes',
#  'Obesity',
#  'Heart Attack',
#  'Stroke',
#  'Other Cardiac',
#  'Pulmonary Asthma',
#  'Alzheimer or Dementia',
#  'Kidney Disease',
#  'Liver Disease',
#  'Endocrine Condition',
#  'Neurological Condition',
#  'Traumatic Brain Injury',
#  'Joint Disease',
#  'Cancer',
#  'Other Chronic Med Condition',
#  'No Chronic Med Condition',
#  'Unknown Chronic Med Condition',
#  'Smokes',
#  'Received Smoking Medication',
#  'Received Smoking Counseling',
#  'Serious Mental Illness',
#  'Principal Diagnosis Class',
#  'Additional Diagnosis Class',
#  'SSI Cash Assistance',
#  'SSDI Cash Assistance',
#  'Veterans Disability Benefits',
#  'Veterans Cash Assistance',
#  'Public Assistance Cash Program',
#  'Other Cash Benefits',
#  'Medicaid and Medicare Insurance',
#  'Unknown Insurance Coverage',
#  'No Insurance',
#  'Medicaid Insurance',
#  'Medicaid Managed Insurance',
#  'Medicare Insurance',
#  'Private Insurance',
#  'Child Health Plus Insurance',
#  'Other Insurance',
#  'Criminal Justice Status',
#  'Three Digit Residence Zip Code']

# %%
df2 = pd.DataFrame(df)
df2.drop(['Survey Year',
         'Veteran Status',
         'Employment Status',
         'Number Of Hours Worked Each Week',
         'Special Education Services',
         'Mental Illness',
         'Intellectual Disability',
         'Autism Spectrum',
         'Other Developmental Disability',
         'Alcohol Related Disorder',
         'Drug Substance Disorder',
         'Mobility Impairment Disorder',
         'Hearing Visual Impairment',
         'Hyperlipidemia',
         'High Blood Pressure',
         'Diabetes',
         'Obesity',
         'Heart Attack',
         'Stroke',
         'Other Cardiac',
         'Pulmonary Asthma',
         'Alzheimer or Dementia',
         'Kidney Disease',
         'Liver Disease',
         'Endocrine Condition',
         'Neurological Condition',
         'Traumatic Brain Injury',
         'Joint Disease',
         'Cancer',
         'Other Chronic Med Condition',
         'No Chronic Med Condition',
         'Unknown Chronic Med Condition',
         'Smokes',
         'Received Smoking Medication',
         'Received Smoking Counseling',
         'Serious Mental Illness',
         'Principal Diagnosis Class',
         'Additional Diagnosis Class',
         'SSI Cash Assistance',
         'SSDI Cash Assistance',
         'Veterans Disability Benefits',
         'Veterans Cash Assistance',
         'Public Assistance Cash Program',
         'Other Cash Benefits',
         'Criminal Justice Status',
         'Three Digit Residence Zip Code'],axis = 1, inplace = True)
display(df2)
# Out:
#        Program Category         Region Served Age Group     Sex  \
# 0            OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 1               SUPPORT        WESTERN REGION     ADULT  FEMALE
# 2            OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 3            OUTPATIENT  NEW YORK CITY REGION     ADULT  FEMALE
# 4            OUTPATIENT     CENTRAL NY REGION     ADULT    MALE
# ...                 ...                   ...       ...     ...
# 187187      RESIDENTIAL        WESTERN REGION     ADULT    MALE
# 187188       OUTPATIENT        WESTERN REGION     ADULT    MALE
# 187189        EMERGENCY        WESTERN REGION     ADULT  FEMALE
# 187190      RESIDENTIAL  NEW YORK CITY REGION     ADULT  FEMALE
# 187191       OUTPATIENT     CENTRAL NY REGION     CHILD  FEMALE
#
#                 Transgender        Sexual Orientation  \
# 0       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 1       NO, NOT TRANSGENDER                   UNKNOWN
# 2       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 3       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 4       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# ...                     ...                       ...
# 187187  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187188  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187189  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187190  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187191  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
#
#              Hispanic Ethnicity          Race        Living Situation  \
# 0       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 1       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 2       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 3       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 4       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# ...                         ...           ...                     ...
# 187187     YES, HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187188  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187189  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187190     YES, HISPANIC/LATINO  MULTI-RACIAL  OTHER LIVING SITUATION
# 187191  NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
#
#           Household Composition  ...              Education Status  \
# 0       COHABITATES WITH OTHERS  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 1                   LIVES ALONE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 2       COHABITATES WITH OTHERS  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 3                   LIVES ALONE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 4                   LIVES ALONE  ...                  SOME COLLEGE
# ...                         ...  ...                           ...
# 187187           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187188           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187189           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187190           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187191  COHABITATES WITH OTHERS  ...          PRE-K TO FIFTH GRADE
#
#        Medicaid and Medicare Insurance Unknown Insurance Coverage  \
# 0                                   NO                         NO
# 1                                  YES                         NO
# 2                                   NO                         NO
# 3                                  YES                         NO
# 4                                   NO                        YES
# ...                                ...                        ...
# 187187                              NO                         NO
# 187188                             YES                         NO
# 187189                              NO                         NO
# 187190                              NO                         NO
# 187191                              NO                         NO
#
#        No Insurance Medicaid Insurance Medicaid Managed Insurance  \
# 0                NO                YES                        YES
# 1                NO                YES                    UNKNOWN
# 2                NO                YES                         NO
# 3                NO                YES                         NO
# 4                NO                 NO             NOT APPLICABLE
# ...             ...                ...                        ...
# 187187           NO                YES                        YES
# 187188           NO                YES                        YES
# 187189           NO                YES                        YES
# 187190           NO                YES                         NO
# 187191           NO                YES                         NO
#
#        Medicare Insurance Private Insurance Child Health Plus Insurance  \
# 0                      NO                NO                          NO
# 1                     YES                NO                          NO
# 2                      NO                NO                          NO
# 3                     YES                NO                          NO
# 4                      NO                NO                          NO
# ...                   ...               ...                         ...
# 187187                 NO                NO                          NO
# 187188                YES                NO                          NO
# 187189                 NO                NO                          NO
# 187190                 NO                NO                          NO
# 187191                 NO                NO                          NO
#
#        Other Insurance
# 0                   NO
# 1                   NO
# 2                   NO
# 3                   NO
# 4                   NO
# ...                ...
# 187187              NO
# 187188              NO
# 187189              NO
# 187190              NO
# 187191              NO
#
# [187192 rows x 21 columns]

# %%
df2.fillna(0, inplace = True)
display(df2)
# Out:
#        Program Category         Region Served Age Group     Sex  \
# 0            OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 1               SUPPORT        WESTERN REGION     ADULT  FEMALE
# 2            OUTPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 3            OUTPATIENT  NEW YORK CITY REGION     ADULT  FEMALE
# 4            OUTPATIENT     CENTRAL NY REGION     ADULT    MALE
# ...                 ...                   ...       ...     ...
# 187187      RESIDENTIAL        WESTERN REGION     ADULT    MALE
# 187188       OUTPATIENT        WESTERN REGION     ADULT    MALE
# 187189        EMERGENCY        WESTERN REGION     ADULT  FEMALE
# 187190      RESIDENTIAL  NEW YORK CITY REGION     ADULT  FEMALE
# 187191       OUTPATIENT     CENTRAL NY REGION     CHILD  FEMALE
#
#                 Transgender        Sexual Orientation  \
# 0       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 1       NO, NOT TRANSGENDER                   UNKNOWN
# 2       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 3       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 4       NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# ...                     ...                       ...
# 187187  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187188  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187189  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187190  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
# 187191  NO, NOT TRANSGENDER  STRAIGHT OR HETEROSEXUAL
#
#              Hispanic Ethnicity          Race        Living Situation  \
# 0       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 1       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 2       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 3       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# 4       NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
# ...                         ...           ...                     ...
# 187187     YES, HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187188  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187189  NO, NOT HISPANIC/LATINO    BLACK ONLY  OTHER LIVING SITUATION
# 187190     YES, HISPANIC/LATINO  MULTI-RACIAL  OTHER LIVING SITUATION
# 187191  NO, NOT HISPANIC/LATINO    WHITE ONLY       PRIVATE RESIDENCE
#
#           Household Composition  ...              Education Status  \
# 0       COHABITATES WITH OTHERS  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 1                   LIVES ALONE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 2       COHABITATES WITH OTHERS  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 3                   LIVES ALONE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 4                   LIVES ALONE  ...                  SOME COLLEGE
# ...                         ...  ...                           ...
# 187187           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187188           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187189           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187190           NOT APPLICABLE  ...  MIDDLE SCHOOL TO HIGH SCHOOL
# 187191  COHABITATES WITH OTHERS  ...          PRE-K TO FIFTH GRADE
#
#        Medicaid and Medicare Insurance Unknown Insurance Coverage  \
# 0                                   NO                         NO
# 1                                  YES                         NO
# 2                                   NO                         NO
# 3                                  YES                         NO
# 4                                   NO                        YES
# ...                                ...                        ...
# 187187                              NO                         NO
# 187188                             YES                         NO
# 187189                              NO                         NO
# 187190                              NO                         NO
# 187191                              NO                         NO
#
#        No Insurance Medicaid Insurance Medicaid Managed Insurance  \
# 0                NO                YES                        YES
# 1                NO                YES                    UNKNOWN
# 2                NO                YES                         NO
# 3                NO                YES                         NO
# 4                NO                 NO             NOT APPLICABLE
# ...             ...                ...                        ...
# 187187           NO                YES                        YES
# 187188           NO                YES                        YES
# 187189           NO                YES                        YES
# 187190           NO                YES                         NO
# 187191           NO                YES                         NO
#
#        Medicare Insurance Private Insurance Child Health Plus Insurance  \
# 0                      NO                NO                          NO
# 1                     YES                NO                          NO
# 2                      NO                NO                          NO
# 3                     YES                NO                          NO
# 4                      NO                NO                          NO
# ...                   ...               ...                         ...
# 187187                 NO                NO                          NO
# 187188                YES                NO                          NO
# 187189                 NO                NO                          NO
# 187190                 NO                NO                          NO
# 187191                 NO                NO                          NO
#
#        Other Insurance
# 0                   NO
# 1                   NO
# 2                   NO
# 3                   NO
# 4                   NO
# ...                ...
# 187187              NO
# 187188              NO
# 187189              NO
# 187190              NO
# 187191              NO
#
# [187192 rows x 21 columns]

# %%
region_counts = df2['Region Served'].value_counts()
display(region_counts)
# Out:
# NEW YORK CITY REGION    93938
# WESTERN REGION          31364
# HUDSON RIVER REGION     27823
# CENTRAL NY REGION       20190
# LONG ISLAND REGION      13877
# Name: Region Served, dtype: int64

# %%
region_counts = df2['Region Served'].value_counts()
plt.figure(figsize=(10,4))
plt.bar(region_counts.index,region_counts.values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Number of Patients by Region')
plt.xticks(rotation = 20)

for i, v in enumerate(region_counts.values):
    plt.text(i, v, str(v), ha='center', va='bottom')
    
plt.show()

# %%
race_counts = df['Race']
plt.figure(figsize=(4,4))

frequency_table = df2['Race'].value_counts()
percentage_table = frequency_table / frequency_table.sum() * 100

percentage_table = percentage_table.round(2)
percentage_table = percentage_table.reset_index()
percentage_table.columns = ['Race','Percentage']

labels = percentage_table['Race']
sizes = percentage_table['Percentage']
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Distribution of Race/Ethnicity')
# Out:
# Text(0.5, 1.0, 'Distribution of Race/Ethnicity')
