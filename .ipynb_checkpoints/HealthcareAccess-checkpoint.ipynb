# %% [markdown]
# This notebook contains four parts.
#
# <b>Part 1 - Importing Necessary Libraries and Dataset<b>
#
# <b>Part 2 - Data Cleaning<b>
#
# <b>Part 3 - Visualizations<b>
#
# <b>Part 4 - Solutions/Recommendations<b>

# %%
import pandas as pd
import matplotlib .pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('datasets/MDOH_HospitalList.csv')
display(df)
# Out:
#      HCCIS ID                                     Hospital Name  \
# 0           1                                       Avera Tyler
# 1           2                      Abbott Northwestern Hospital
# 2           3                               Essentia Health Ada
# 3           4                       Riverwood Healthcare Center
# 4           6                              Appleton Area Health
# ..        ...                                               ...
# 132       251  Community Behavioral Health Hospital - Rochester
# 133       254     Community Behavioral Health Hospital - Baxter
# 134       256    Community Behavioral Health Hospital - Bemidji
# 135       259                                       PrairieCare
# 136       260                  Sanford Behavioral Health Center
#
#                       System Affiliation  \
# 0                           Avera Health
# 1                   Allina Health System
# 2                        Essentia Health
# ...

# %%
adf = pd.read_csv('datasets/MDOH_AdmissionHospitalsList.csv')
display(adf)
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HCCIS ID                                      Hospital Name
# 1          NaN                                                NaN
# 2            3                                Essentia Health Ada
# 3            4                        Riverwood Healthcare Center
# 4          100  Mayo Clinic Health System - Albert Lea and Aus...
# ..         ...                                                ...
# 136        187                            Woodwinds Health Campus
# 137        177                 Sanford Worthington Medical Center
# 138        186             M Health Fairview Lakes Medical Center
# 139        NaN                                                NaN
# 140        NaN                                                NaN
#
#             Unnamed: 2   Unnamed: 3  Unnamed: 4            Unnamed: 5  \
# 0          Affiliation         City      County  Report Year End Date
# ...
