# %%
import pandas as pd
import matplotlib .pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('datasets/MDOH_HospitalList.csv')
print(df)
# Out:
#      HCCIS ID                                     Hospital Name  \
# 0           1                                       Avera Tyler
# 1           2                      Abbott Northwestern Hospital
# 2           3                               Essentia Health Ada
# 3           4                       Riverwood Healthcare Center
# 4           6                              Appleton Area Health
# ..        ...                                               ...
# 132       251  Community Behavioral Health Hospital - Rochester
# 133       254     Community Behavioral Health Hospital - Baxter
# 134       256    Community Behavioral Health Hospital - Bemidji
# 135       259                                       PrairieCare
# 136       260                  Sanford Behavioral Health Center
#
#                       System Affiliation  \
# 0                           Avera Health
# 1                   Allina Health System
# 2                        Essentia Health
# ...

# %%
df.head()
# Out:
#    HCCIS ID                 Hospital Name    System Affiliation  \
# 0         1                   Avera Tyler          Avera Health
# 1         2  Abbott Northwestern Hospital  Allina Health System
# 2         3           Essentia Health Ada       Essentia Health
# 3         4   Riverwood Healthcare Center        No Affiliation
# 4         6          Appleton Area Health        No Affiliation
#
#                                            Ownership  \
# 0  Nonprofit Corporation (nongovernmental, nonpro...
# 1  Nonprofit Corporation (nongovernmental, nonpro...
# 2  Nonprofit Corporation (nongovernmental, nonpro...
# 3  Nonprofit Corporation (nongovernmental, nonpro...
# 4                    City (governmental, nonfederal)
#
#                       Address         City    County State    Zip  \
# 0           240 Willow Street        Tyler   Lincoln    MN  56178
# 1        800 East 28th Street  Minneapolis  Hennepin    MN  55407
# ...
